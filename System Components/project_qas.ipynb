# %%
# !pip install streamlit
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 8.2MB 7.6MB/s
# ...
#      |████████████████████████████████| 81kB 12.2MB/s
# ...
#      |████████████████████████████████| 174kB 51.3MB/s
# ...
#      |████████████████████████████████| 112kB 56.0MB/s
# ...
#      |████████████████████████████████| 4.2MB 41.6MB/s
# ...
#      |████████████████████████████████| 71kB 10.3MB/s
# ...
#      |████████████████████████████████| 122kB 54.4MB/s
# ...
#   Created wheel for blinker: filename=blinker-1.4-cp37-none-any.whl size=13448 sha256=042fc65493799729805053e1eb723b35e29854daa0e58d844a3a4ab85120d20a
#   Stored in directory: /root/.cache/pip/wheels/92/a0/00/8690a57883956a301d91cf4ec999cc0b258b01e3f548f86e89
# Successfully built blinker
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.5 which is incompatible.
# ...
#   Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
# ...
#      |████████████████████████████████| 747kB 6.8MB/s
# ...

# %%
# !apt install libpoppler-cpp-dev
# !pip install pdftotext
# !pip install transformers
# !python -m nltk.downloader punkt
# !pip install sentencepiece
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libpoppler-cpp0v5
# The following NEW packages will be installed:
#   libpoppler-cpp-dev libpoppler-cpp0v5
# 0 upgraded, 2 newly installed, 0 to remove and 34 not upgraded.
# Need to get 36.7 kB of archives.
# After this operation, 188 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp0v5 amd64 0.62.0-2ubuntu2.12 [28.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-cpp-dev amd64 0.62.0-2ubuntu2.12 [8,676 B]
# Fetched 36.7 kB in 1s (65.0 kB/s)
# Selecting previously unselected package libpoppler-cpp0v5:amd64.
# (Reading database ... 160706 files and directories currently installed.)
# ...

# %%
# Upload the src.zip folder here in google colab and then extract
# !unzip src.zip
# %cd src
# Out:
# Archive:  src.zip
#    creating: src/
#   inflating: src/Main.py
#    creating: src/legal_docs/
#   inflating: src/legal_docs/The Advocates' Welfare Fund Act, 2001.pdf
#    creating: src/legal_docs/uploads/
#   inflating: src/legal_docs/uploads/temp.txt
#   inflating: src/legal_docs/The All India Council for Technical Education Act, 1987.pdf
#   inflating: src/legal_docs/The Sexual Harassment of Women at Workplace Act, 2013.pdf
#   inflating: src/legal_docs/The Anti-Hijacking Act, 2016.pdf
#   inflating: src/legal_docs/The Armed Forces Tribunal Act, 2007.pdf
#   inflating: src/legal_docs/The Bureau of Indian Standards Act, 2016.pdf
#   inflating: src/legal_docs/The Coinage Act, 2011.pdf
#   inflating: src/legal_docs/The Pension Fund Regulatory and Development Authority Act, 2013.pdf
#   inflating: src/legal_docs/The Prohibition of Employment as Manual Scavengers and their Rehabilitation Act, 2013.pdf
# ...

# %%
# !streamlit run app.py &>/dev/null&
# Wait for about 2.5 minutes after running this cell, to download and initialize the models

# %%
from pyngrok import ngrok
# Setup a tunnel to the streamlit port 8501
public_url = ngrok.connect(8501)
public_url
# Out:
# <NgrokTunnel: "http://c89220b3bfe0.ngrok.io" -> "http://localhost:8501">

# %%
# Run this and the below cells when the app is to be shutdown
# !pgrep streamlit
# Out:
# 252

# %%
# !kill 252
# !ps -l
# Out:
# F S   UID     PID    PPID  C PRI  NI ADDR SZ WCHAN  TTY          TIME CMD
# 4 S     0       1       0  0  80   0 - 85467 epoll_ ?        00:00:01 node
# 4 S     0      14       0  0  80   0 -  8974 hrtime ?        00:00:00 tail
# 4 S     0      46       1  0  80   0 - 53151 epoll_ ?        00:00:02 jupyter-no
# 4 S     0      47       1  0  80   0 - 177531 futex_ ?       00:00:01 dap_multip
# 4 S     0      58      46  0  80   0 - 174517 select ?       00:00:06 python3
# 1 S     0      78       1  0  80   0 - 32039 futex_ ?        00:00:03 python3
# 4 R     0     252       1 17  80   0 - 5854366 -    ?        00:04:04 streamlit
# 4 S     0     324      58  0  80   0 - 181728 futex_ ?       00:00:02 ngrok
# 4 R     0     449      58  0  80   0 - 12647 -      ?        00:00:00 ps

# %%
# ngrok.kill()
